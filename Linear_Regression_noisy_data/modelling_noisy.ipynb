# %% [markdown]
# # Predictive Modeling Example
#
# In this notebook, we will use the synthetic dataset we generated to build a predictive model. We will use the OLS (Ordinary Least Squares) method to do this. This is a simple linear regression model that we will use to predict the value of the dependent variable (y) based on the value of the independent variable (x).

# %% [markdown]
# ## Step 1: Import the libraries we will use in this notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

np.random.seed(1) # set this to ensure the results are repeatable.

# %% [markdown]
# ## Step 2: Load the given data that we will model

# %%
import os
print(os.getcwd())
# Out:
# /Users/poorna/Documents/USF/DM-ISM6136/Week-2/_W02

# %%
df = pd.read_csv(r'/Users/poorna/Documents/USF/DM-ISM6136/Week-2/_W02/dataset_noisy.csv')

df.head(3)
# Out:
#    input  target
# 0  16.24  346.18
# 1  -6.12 -267.29
# 2  -5.28  -98.02

# %% [markdown]
# Seperate out the input m(X) and the target (y)

# %%
X=df[['input']]
y=df[['target']]

# %% [markdown]
# For educational purposes, let's look at the first five values in X and y (note how X is an array of lists)

# %% [markdown]
# ## Step 3: Explore the given data
#
# Often we will do much more than this, but at least look at things using a scatterplot

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')

ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Fit the model
#
# Fit the linear regression model to the dataset

# %%
lin_reg=LinearRegression()
_ = lin_reg.fit(X,y) # note the underscore. This is a convention to indicate that the output is not used.


# OR, we could combine the two lines above to one as follows...
#lin_reg = LinearRegression().fit(X,y)

# %% [markdown]
# ## Step 5: Analyze the linear regression model's performance

# %% [markdown]
# Visualize the linear regression model results

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(X, y, color='red')
ax.scatter(X, lin_reg.predict(X), color='blue')

ax.set_title('Linear Regression')
ax.set_xlabel('input')
ax.set_ylabel('target')
plt.tight_layout()
plt.show()

# %%
b0 = lin_reg.intercept_[0]
b1 = lin_reg.coef_[0][0]
r2 = lin_reg.score(X, y)

# %% [markdown]
# ... using fstring formatting, we can display these values as follows...

# %%
print(f"Y = {b0:.2f} + {b1:.2f}x")
print(f"R^2: {lin_reg.score(X, y):.3f}") 
# for more on fstrings see here...
# https://www.freecodecamp.org/news/python-f-strings-tutorial-how-to-use-f-strings-for-string-formatting/
# Out:
# Y = 18.60 + 14.23x
# R^2: 0.293

# %% [markdown]
# # Impact of extra noise on the model.

# %% [markdown]
# ### With the increase in noise, the R^2 value is decreased from 0.699 to 0.293. Also the b1 and b0 values are more far apart from the target value. So with increase in noise, model became underfit and less accurate.
#
# ### R^2 is a statistical measure that represents the proportion of variance in the dependent variable "Y" that is explained by the independent variable "X" in the linear regression model. It quantifies the goodness of the fit of the model to the data.
#
# ### The R^2 value of 0.293 means that there is some portion of the variance in the dependent variable. The closer R2 is to 1, the better the model fits the data.
